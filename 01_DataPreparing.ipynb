# %% [markdown]
# # DataPreparing
#
# THe first step of our notebooks will be to run a DataPreparing script.
# This contains all the necessary code to transform our original images into images that are ready for AI training.
#
# To benefit from the perks of our Azure cloud service, we will be creating a new dataset to store our processed images.
#
# Follow along in the HackMD documents to answer some questions introduced in these notebooks.
#
# If you want more background information on these notebooks, the HackMD documents will help you as well.

# %% [markdown]
# ## Setup
#
# Our virtual machine might not have all packages installed yet. So let's go and install some packages.
# We can use cell-magic for this, which will allow us to stay inside this notebook and just executing the cells.
#
# Later on, these cells might nog be necessary anymore, which is why we include it at the top. During other builds, you can just ignore these.
#
# As a best practice, let's make sure to only work on the version we know is safe. This is a great way to organising our AI projects. By keeping the versions linked like this, no unexpected new version would break our code!

# %%
# %%writefile requirements.txt
#
# opencv-python==4.5.4.60
# Out:
# Writing requirements.txt

# %%
# We want to make sure to use the right AzureML packages!
# !/anaconda/envs/azureml_py38_PT_TF/bin/python -m pip install -r requirements.txt
# Out:
# Collecting opencv-python==4.5.4.60
#   Downloading opencv_python-4.5.4.60-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (60.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.3/60.3 MB 4.9 MB/s eta 0:00:00:00:0100:01
# Requirement already satisfied: numpy>=1.17.3 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from opencv-python==4.5.4.60->-r requirements.txt (line 2)) (1.23.4)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.5.4.60

# %%
# This cell can be used to fill in some values that you will be referring to in the coming cells
train_test_split_factor = 0.20

# %%
# Importing the default packages for data processing and visualisation
import numpy as np # Used to process our images in a data-format
import matplotlib.pyplot as plt # visualise the images
import cv2 # Process the images


import os
from glob import glob
import math

import warnings
warnings.filterwarnings("ignore") # Warnings that can be ignored will be ignored

import random
SEED = 42 # Everytime you want to randomize items, use this `random.seed(SEED)` option. This way, you are always having the same randomization as I have.
random.seed(SEED)

# %%
# Import AzureML packages
from azureml.core import Workspace
from azureml.core import Dataset
from azureml.data.datapath import DataPath
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget

# %% [markdown]
# ## Step 1: Connecting to the Azure ML Workspace
#
# Azure Machine Learning needs to connect through the Azure SDK with the Workspace object. This contains all the information inside of this 'Laboratory'

# %% [markdown]
# The information below should reflect your situation regarding Azure. You should have a ResourceGroup called '04_AzureML' and a workspace name called 'segersnathan' if you followed my instructions on HackMD.
# The subscription ID, however, is something that has been created by Azure itself.
#
# Luckily, this ML studio gives us a quick way to find this information.
# Click on the \/-arrow in the upper-right corner over there ↗️, next to your profile picture.
#
# Most of your information is in there as well, but you still can't find your subscription_**id** there ...
#
# Press the 'Download config' option, and you'll be left with this information:
#
# ```json
# {
#     "subscription_id": "7c50f9c3-289b-4ae0-a075-08784b3b9042",
#     "resource_group": "NathanReserve",
#     "workspace_name": "segersnathan"
# }
# ```
#
# Which gives you exactly the information you need 🥰
#
# There's also an option to use this configuration itself. Search for the documentation on how to do it: https://docs.microsoft.com/en-us/python/api/azureml-core/azureml.core.workspace(class)?view=azure-ml-py

# %%
## Either get environment variables, or a fallback name, which is the second parameter.
## Currently, fill in the fallback values. Later on, we will make sure to work with Environment values. So we're already preparing for it in here!
workspace_name = os.environ.get('WORKSPACE', 'felix-platteau-ml')
subscription_id = os.environ.get('SUBSCRIPTION_ID', '9ae53766-1df1-4559-8ad6-262ddacf26b7')
resource_group = os.environ.get('RESOURCE_GROUP', 'mlops')

# %%
ws = Workspace.get(name=workspace_name,
               subscription_id=subscription_id,
               resource_group=resource_group)

# %%
ws
# Out:
# Workspace.create(name='felix-platteau-ml', subscription_id='9ae53766-1df1-4559-8ad6-262ddacf26b7', resource_group='mlops')

# %% [markdown]
# ## Step 2 -- Data preparing
#
# Let's get started preparing our data.
# The original dataset contains images of rice, but are not yet ready for AI processing.
# They are all different shapes and sizes, so they need to be processed.
#
# I could've done it earlier on and given you the processed data, but that's not really that fun, isn't it 😉
#
# By performing these steps, you see how you can create datasets in a Programmatoric way, and upload new data.
# We will make use of the Azure Machine Learning tools to easily manage all of our datasets in a structured way.
#
# ## Step 2.1 -- Checking our data
#
# Let us first explore how the data looks. We'll create 3 subdirectories under a data directory, one for each rice.
# If you want to update this to more rice later, simply adapt the `RICES` list.

# %%
RICES = ['Arborio_v1', 'Basmati_v1', 'Ipsala_v1', 'Jasmine_v1', 'Karacadag_v1'] # As we have three classes, let's just defined them hoor. This way we can easily loop over them later.
# We can also work with ENUM's if you want another fun way of accessing properties:
# Feel free to uncomment these lines, I won't work with them, but you can always do so if yoi prefer


# from enum import Enum
# rice = Enum('rice', 'CATS DOGS PANDAS')

# print(list(rice))
# print(rice.CATS.name.lower()) # You can always get their effective string values this way

# %% [markdown]
# We will need to create temporary directories to store the images while we process them.
# This script will create a `data` folder, and then make subdirectories for each animal.

# %%
data_folder = os.path.join(os.getcwd(), 'data')
os.makedirs(data_folder, exist_ok=True)
for rice_name in RICES:
    os.makedirs(os.path.join(data_folder, 'rice', rice_name), exist_ok=True)

# %%
# Get all the datasets that were registered in the UI
# We can then easily select the ones we need
datasets = Dataset.get_all(workspace=ws) # Make sure to give our workspace with it
print(datasets)
# Out:
# { 'Arborio_v1': DatasetRegistration(id='23aa2c70-2e22-4f07-aa02-fd8b6f3c10ba', name='Arborio_v1', version=1, description='', tags={}),
#   'Basmati_v1': DatasetRegistration(id='d9c164c7-a5a1-4f6d-a050-4e4ff1c2f35a', name='Basmati_v1', version=1, description='', tags={}),
#   'Ipsala_v1': DatasetRegistration(id='0bf0349b-ac3b-4459-95ba-e0f6fdc5da38', name='Ipsala_v1', version=1, description='', tags={}),
#   'Jasmine_v1': DatasetRegistration(id='67f20d87-a70d-4657-92a9-5a83a0e3711a', name='Jasmine_v1', version=1, description='', tags={}),
#   'Karacadag_v1': DatasetRegistration(id='1a7c3105-f8b1-43fd-956d-a1d3b20d4f58', name='Karacadag_v1', version=1, description='', tags={})}

# %% [markdown]
# ### **TODO for students**
#
# Write a check to see if we have our three datasets!!

# %%
# Write your answer here

# %% [markdown]
# Uncomment the next cell to show a possible answer

# %%
# %load code_solutions/CheckDatasets.txt
def checkDatasets():
    if all(rice in list(datasets.keys()) for rice in RICES):
        print("All datasets are available!")
    else:
        print("Your are missing some datasets.")
checkDatasets()
# Out:
# All datasets are available!

# %%
from typing import List
def downloadTestImagesForRice(rice_name: str, amount_of_test_images: int) -> List[str]:
    """
    Download test images from an Azure dataset.
    Choose the amount of test images per rice you want.
    The images will be downloaded to the `data/<rice>` directory

    Parameters:
        rice_name (str): The name of the dataset / rice to download images from
        amount_of_test_images (int): The amount of test images to download
    Returns:
        file_paths (List[str]): list of file paths to display the images
    """
    rice_dataset = datasets[rice_name]
    test_images = rice_dataset.take(amount_of_test_images)
    file_paths = test_images.download(os.path.join(data_folder, 'rice', rice_name), overwrite=True)
    return file_paths

def displayTestImages(images: List[str]) -> None:
    fig, axes = plt.subplots(1, len(images), figsize=(12, 9), sharey=True)
    axes_1d = axes.ravel()
    for i in range(0, len(images)):    
        axes_1d[i].imshow(plt.imread(images[i]), cmap='gray')
        axes_1d[i].axis('off')
        
    plt.show()

# %% [markdown]
# Choose a number of images you want to show the users

# %%
rice_images = {}
AMOUNT_OF_IMAGES = 5
for rice_name in RICES:
    print(f"Downloading {AMOUNT_OF_IMAGES} images of {rice_name}...")
    rice_images[rice_name] = {}
    rice_images[rice_name]['images'] = downloadTestImagesForRice(rice_name, AMOUNT_OF_IMAGES)
# Out:
# Downloading 5 images of Arborio_v1...
# Downloading 5 images of Basmati_v1...
# Downloading 5 images of Ipsala_v1...
# Downloading 5 images of Jasmine_v1...
# Downloading 5 images of Karacadag_v1...

# %%
displayTestImages(rice_images['Karacadag_v1']['images'])

# %% [markdown]
# ### Step 2.2 Processing and uploading the resized images
#
# Like we said in the introduction, we'll need to resize the images so they're all the same shape and size.
# We are getting ready for a CNN model, which will require an input of 64, 64. You can go higher, but then it'll take longer to train, but also improve the accuracy.

# %%
# Let's create a mounth point. Think of it like your D:/ drive on your PC
# mount_path = os.path.join(os.getcwd(), 'mount')
mount_path = os.path.join('/home/azureuser/cloudfiles/data')
os.makedirs(mount_path, exist_ok=True)

# %%
# Defien a path to store the rice images onto. We'll choose for `data/processed/rice` this time. Again, create subdirectories for all the rice
processed_path = os.path.join(mount_path, 'processed', 'rice')
os.makedirs(processed_path, exist_ok=True)
for rice_name in RICES:
    os.makedirs(os.path.join(processed_path, rice_name), exist_ok=True)

# %%
# Defien a path to store the rice images onto. We'll choose for `data/processed/rice` this time. Again, create subdirectories for all the rice
original_path = os.path.join(mount_path, 'original', 'rice')
os.makedirs(original_path, exist_ok=True)
for rice_name in RICES:
    os.makedirs(os.path.join(original_path, rice_name), exist_ok=True)

# %%
# !ls $mount_path
# !ls $mount_path/processed/rice
# !ls $mount_path/original/rice
# Out:
# original  processed
# Arborio_v1  Basmati_v1	Ipsala_v1  Jasmine_v1  Karacadag_v1
# Arborio_v1  Basmati_v1	Ipsala_v1  Jasmine_v1  Karacadag_v1

# %%
def mountProcessAndUploadRiceImages(rice_name):

    # The mount context is to load in the dataset to our directory.
    # Make sure to stop it when it's finished!

    # Get the dataset name for this rice, then mount to the directory
    mounted_context = datasets[rice_name].mount(os.path.join(mount_path, 'original', 'rice', rice_name))
    print('Starting the Mount context, to get all the original images.')
    mounted_context.start()

    # Get all the image paths with the `glob()` method.
    print(f'Resizing all images for {rice_name} ...')
    imagePaths = glob(f"{mount_path}/original/rice/{rice_name}/*.jpg")

    # Process all the images with OpenCV. Reading them, then resizing them to 64x64 and saving them once more.
    print(f"Processing {len(imagePaths)} images")
    for imagePath in imagePaths:
        image = cv2.imread(imagePath)
        image = cv2.resize(image, (64, 64)) # Resize to a square of 64, 64
        cv2.imwrite(os.path.join(processed_path, rice_name, imagePath.split('/')[-1]), image)
    print(f'... done resizing. Stopping context now...')
    
    # Upload the directory as a new dataset
    print(f'Uploading directory now ...')
    resized_dataset = Dataset.File.upload_directory(
                        # Enter the sourece directory on our machine where the resized pictures are
                        src_dir = os.path.join(processed_path, rice_name),
                        # Create a DataPath reference where to store our images to. We'll use the default datastore for our workspace.
                        target = DataPath(datastore=ws.get_default_datastore(), path_on_datastore=f'processed_rice/{rice_name}'),
                        overwrite=True)
    # Make sure to register the dataset whenever everything is uploaded.
    resized_dataset.register(ws,
                            name=f'resized_{rice_name}',
                            description=f'{rice_name} images resized tot 64, 64',
                            tags={'rice': rice_name, 'AI-Model': 'CNN'}, # Optional tags, can always be interesting to keep track of these!
                            create_new_version=True)
    print(f'... Done')
    # Stop the context now.
    mounted_context.stop()
    print(f"... Context stopped and freed.")

# %%
# %%time
# Process all the rice images now. This can take a while!
# We'll use Cell magic once more, to time how long this takes!
mountProcessAndUploadRiceImages('Arborio_v1')
mountProcessAndUploadRiceImages('Basmati_v1')
mountProcessAndUploadRiceImages('Ipsala_v1')
mountProcessAndUploadRiceImages('Jasmine_v1')
mountProcessAndUploadRiceImages('Karacadag_v1')
# Out:
# Starting the Mount context, to get all the original images.
# Resizing all images for Arborio_v1 ...
# Processing 1000 images
# ... done resizing. Stopping context now...
# Uploading directory now ...
# Validating arguments.
# Arguments validated.
# Uploading file to processed_rice/Arborio_v1
# Uploading an estimated of 1000 files
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(686).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(686).jpg, 1 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(157).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(157).jpg, 2 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(274).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(274).jpg, 3 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(558).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(558).jpg, 4 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(931).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(931).jpg, 5 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(808).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(808).jpg, 6 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(26).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(26).jpg, 7 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(667).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(667).jpg, 8 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(278).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(278).jpg, 9 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(15).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(15).jpg, 10 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(223).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(223).jpg, 11 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(276).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(276).jpg, 12 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(702).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(702).jpg, 13 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(187).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(187).jpg, 14 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(892).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(892).jpg, 15 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(100).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(100).jpg, 16 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(279).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(279).jpg, 17 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(110).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(110).jpg, 18 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(610).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(610).jpg, 19 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(377).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(377).jpg, 20 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(537).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(537).jpg, 21 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(530).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(530).jpg, 22 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(565).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(565).jpg, 23 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(86).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(86).jpg, 24 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(75).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(75).jpg, 25 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(684).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(684).jpg, 26 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(303).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(303).jpg, 27 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(317).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(317).jpg, 28 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(130).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(130).jpg, 29 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(693).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(693).jpg, 30 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(496).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(496).jpg, 31 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(685).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(685).jpg, 32 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(494).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(494).jpg, 33 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(103).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(103).jpg, 34 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(890).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(890).jpg, 35 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(713).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(713).jpg, 36 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(802).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(802).jpg, 37 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(304).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(304).jpg, 38 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(945).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(945).jpg, 39 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(742).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(742).jpg, 40 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(82).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(82).jpg, 41 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(23).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(23).jpg, 42 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(897).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(897).jpg, 43 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(182).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(182).jpg, 44 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(966).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(966).jpg, 45 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(859).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(859).jpg, 46 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(726).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(726).jpg, 47 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(159).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(159).jpg, 48 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(906).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(906).jpg, 49 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(50).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(50).jpg, 50 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(53).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(53).jpg, 51 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(768).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(768).jpg, 52 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(773).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(773).jpg, 53 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(218).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(218).jpg, 54 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(28).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(28).jpg, 55 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(357).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(357).jpg, 56 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(108).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(108).jpg, 57 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(155).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(155).jpg, 58 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(417).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(417).jpg, 59 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(266).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(266).jpg, 60 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(823).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(823).jpg, 61 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(511).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(511).jpg, 62 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(706).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(706).jpg, 63 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(39).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(39).jpg, 64 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(900).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(900).jpg, 65 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(516).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(516).jpg, 66 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(144).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(144).jpg, 67 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(869).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(869).jpg, 68 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(594).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(594).jpg, 69 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(180).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(180).jpg, 70 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(746).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(746).jpg, 71 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(696).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(696).jpg, 72 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(152).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(152).jpg, 73 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(58).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(58).jpg, 74 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(927).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(927).jpg, 75 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(730).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(730).jpg, 76 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(247).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(247).jpg, 77 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(923).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(923).jpg, 78 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(735).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(735).jpg, 79 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(74).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(74).jpg, 80 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(641).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(641).jpg, 81 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(531).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(531).jpg, 82 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(1000).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(1000).jpg, 83 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(912).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(912).jpg, 84 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(661).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(661).jpg, 85 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(450).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(450).jpg, 86 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(120).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(120).jpg, 87 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(722).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(722).jpg, 88 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(88).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(88).jpg, 89 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(887).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(887).jpg, 90 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(427).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(427).jpg, 91 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(67).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(67).jpg, 92 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(215).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(215).jpg, 93 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(645).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(645).jpg, 94 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(829).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(829).jpg, 95 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(627).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(627).jpg, 96 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(749).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(749).jpg, 97 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(248).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(248).jpg, 98 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(578).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(578).jpg, 99 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(71).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(71).jpg, 100 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(800).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(800).jpg, 101 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(145).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(145).jpg, 102 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(114).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(114).jpg, 103 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(473).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(473).jpg, 104 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(784).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(784).jpg, 105 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(253).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(253).jpg, 106 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(986).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(986).jpg, 107 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(716).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(716).jpg, 108 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(484).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(484).jpg, 109 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(567).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(567).jpg, 110 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(791).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(791).jpg, 111 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(723).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(723).jpg, 112 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(899).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(899).jpg, 113 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(346).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(346).jpg, 114 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(519).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(519).jpg, 115 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(10).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(10).jpg, 116 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(294).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(294).jpg, 117 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(485).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(485).jpg, 118 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(219).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(219).jpg, 119 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(839).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(839).jpg, 120 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(856).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(856).jpg, 121 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(408).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(408).jpg, 122 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(668).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(668).jpg, 123 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(540).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(540).jpg, 124 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(241).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(241).jpg, 125 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(573).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(573).jpg, 126 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(957).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(957).jpg, 127 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(592).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(592).jpg, 128 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(583).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(583).jpg, 129 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(585).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(585).jpg, 130 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(683).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(683).jpg, 131 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(833).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(833).jpg, 132 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(115).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(115).jpg, 133 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(288).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(288).jpg, 134 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(259).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(259).jpg, 135 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(629).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(629).jpg, 136 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(255).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(255).jpg, 137 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(671).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(671).jpg, 138 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(636).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(636).jpg, 139 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(96).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(96).jpg, 140 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(102).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(102).jpg, 141 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(206).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(206).jpg, 142 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(411).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(411).jpg, 143 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(320).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(320).jpg, 144 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(119).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(119).jpg, 145 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(828).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(828).jpg, 146 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(451).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(451).jpg, 147 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(124).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(124).jpg, 148 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(323).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(323).jpg, 149 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(285).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(285).jpg, 150 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(555).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(555).jpg, 151 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(826).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(826).jpg, 152 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(429).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(429).jpg, 153 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(953).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(953).jpg, 154 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(4).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(4).jpg, 155 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(161).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(161).jpg, 156 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(552).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(552).jpg, 157 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(622).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(622).jpg, 158 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(200).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(200).jpg, 159 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(615).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(615).jpg, 160 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(422).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(422).jpg, 161 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(33).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(33).jpg, 162 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(827).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(827).jpg, 163 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(902).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(902).jpg, 164 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(430).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(430).jpg, 165 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(930).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(930).jpg, 166 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(819).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(819).jpg, 167 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(162).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(162).jpg, 168 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(737).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(737).jpg, 169 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(979).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(979).jpg, 170 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(48).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(48).jpg, 171 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(62).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(62).jpg, 172 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(372).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(372).jpg, 173 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(164).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(164).jpg, 174 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(964).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(964).jpg, 175 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(11).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(11).jpg, 176 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(426).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(426).jpg, 177 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(662).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(662).jpg, 178 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(595).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(595).jpg, 179 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(177).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(177).jpg, 180 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(83).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(83).jpg, 181 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(404).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(404).jpg, 182 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(302).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(302).jpg, 183 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(54).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(54).jpg, 184 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(908).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(908).jpg, 185 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(272).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(272).jpg, 186 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(560).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(560).jpg, 187 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(911).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(911).jpg, 188 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(478).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(478).jpg, 189 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(435).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(435).jpg, 190 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(824).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(824).jpg, 191 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(409).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(409).jpg, 192 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(670).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(670).jpg, 193 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(498).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(498).jpg, 194 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(358).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(358).jpg, 195 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(18).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(18).jpg, 196 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(680).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(680).jpg, 197 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(838).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(838).jpg, 198 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(549).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(549).jpg, 199 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(760).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(760).jpg, 200 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(786).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(786).jpg, 201 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(503).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(503).jpg, 202 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(3).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(3).jpg, 203 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(198).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(198).jpg, 204 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(325).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(325).jpg, 205 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(166).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(166).jpg, 206 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(796).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(796).jpg, 207 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(151).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(151).jpg, 208 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(355).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(355).jpg, 209 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(634).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(634).jpg, 210 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(307).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(307).jpg, 211 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(937).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(937).jpg, 212 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(190).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(190).jpg, 213 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(545).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(545).jpg, 214 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(948).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(948).jpg, 215 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(458).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(458).jpg, 216 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(461).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(461).jpg, 217 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(782).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(782).jpg, 218 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(258).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(258).jpg, 219 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(920).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(920).jpg, 220 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(950).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(950).jpg, 221 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Arborio_v1/Arborio_(193).jpg
# ...
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(849).jpg, 930 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(262).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(262).jpg, 931 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(202).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(202).jpg, 932 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(77).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(77).jpg, 933 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(622).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(622).jpg, 934 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(265).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(265).jpg, 935 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(924).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(924).jpg, 936 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(631).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(631).jpg, 937 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(771).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(771).jpg, 938 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(81).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(81).jpg, 939 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(475).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(475).jpg, 940 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(349).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(349).jpg, 941 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(828).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(828).jpg, 942 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(363).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(363).jpg, 943 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(853).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(853).jpg, 944 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(824).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(824).jpg, 945 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(437).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(437).jpg, 946 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(959).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(959).jpg, 947 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(195).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(195).jpg, 948 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(893).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(893).jpg, 949 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(792).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(792).jpg, 950 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(487).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(487).jpg, 951 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(267).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(267).jpg, 952 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(106).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(106).jpg, 953 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(504).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(504).jpg, 954 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(760).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(760).jpg, 955 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(418).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(418).jpg, 956 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(162).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(162).jpg, 957 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(91).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(91).jpg, 958 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(968).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(968).jpg, 959 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(593).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(593).jpg, 960 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(886).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(886).jpg, 961 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(445).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(445).jpg, 962 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(881).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(881).jpg, 963 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(645).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(645).jpg, 964 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(641).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(641).jpg, 965 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(152).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(152).jpg, 966 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(144).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(144).jpg, 967 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(528).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(528).jpg, 968 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(465).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(465).jpg, 969 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(122).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(122).jpg, 970 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(359).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(359).jpg, 971 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(114).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(114).jpg, 972 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(80).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(80).jpg, 973 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(858).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(858).jpg, 974 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(818).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(818).jpg, 975 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(765).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(765).jpg, 976 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(350).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(350).jpg, 977 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(409).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(409).jpg, 978 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(126).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(126).jpg, 979 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(811).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(811).jpg, 980 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(29).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(29).jpg, 981 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(592).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(592).jpg, 982 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(721).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(721).jpg, 983 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(203).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(203).jpg, 984 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(689).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(689).jpg, 985 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(620).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(620).jpg, 986 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(676).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(676).jpg, 987 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(956).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(956).jpg, 988 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(579).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(579).jpg, 989 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(24).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(24).jpg, 990 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(35).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(35).jpg, 991 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(927).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(927).jpg, 992 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(20).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(20).jpg, 993 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(396).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(396).jpg, 994 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(38).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(38).jpg, 995 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(257).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(257).jpg, 996 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(329).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(329).jpg, 997 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(66).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(66).jpg, 998 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(422).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(422).jpg, 999 files out of an estimated total of 1000
# Uploading /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(289).jpg
# Uploaded /home/azureuser/cloudfiles/data/processed/rice/Karacadag_v1/Karacadag_(289).jpg, 1000 files out of an estimated total of 1000
# Uploaded 1000 files
# Creating new dataset
# ... Done
# ... Context stopped and freed.
# CPU times: user 31.8 s, sys: 7.03 s, total: 38.8 s
# Wall time: 1min 27s

# %% [markdown]
# Our Animal datasets are now registered onto the datasets of Azure, which is what we need. We can now safely delete all the images from our disk.

# %% [markdown]
# ### **TODO for students**
#
# Delete the images from disk in any way you want.

# %%
# Write your answer here

# %% [markdown]
# Uncomment the next cell to see a possible answer.

# %%
# %load code_solutions/RemoveProcessedDirectories.txt
# Remove the processed directory
import shutil

for rice_name in RICES:
    shutil.rmtree(os.path.join(processed_path, rice_name), )

# %% [markdown]
# ## Step 2.3 -- Create Training and Testing splitted data
#
# As you might remember from previous AI lessons, we want to split up our AI data in a batch of Training and Testing data, with the necessary labels.
# We will take a portion of our data to train on, and the rest will be kept to test and validate our AI model.
#
# For this, I chose a percentage in the first cell:
# `train_test_split_factor = 0.20`

# %%
training_datapaths = []
testing_datapaths = []
default_datastore = ws.get_default_datastore()
for rice_name in RICES:
    # Get the dataset by name
    rice_dataset = Dataset.get_by_name(ws, f"resized_{rice_name}")

    # Get only the .JPG images
    rice_images = [img for img in rice_dataset.to_path() if img.split('.')[-1] == 'jpg']

    ## Concatenate the names for the rice_name and the img_path. Don't put a / between, because the img_path already contains that
    rice_images = [(default_datastore, f'processed_rice/{rice_name}{img_path}') for img_path in rice_images] # Make sure the paths are actual DataPaths
    
    random.seed(SEED) # Use the same random seed as I use and defined in the earlier cells
    random.shuffle(rice_images) # Shuffle the data so it's randomized
    
    ## Testing images
    amount_of_test_images = math.ceil(len(rice_images) * train_test_split_factor) # Get a small percentage of testing images

    rice_test_images = rice_images[:amount_of_test_images]
    rice_training_images = rice_images[amount_of_test_images:]
    
    # Add them all to the other ones
    testing_datapaths.extend(rice_test_images)
    training_datapaths.extend(rice_training_images)

# %% [markdown]
# ### **TODO for students**
#
# Write assertions to see if you have 600 testing images in total, and 200 for each animal.
# Update the values depending on your `train_test_split_factor` of course!
#
# "What are Assertions?"
# https://www.w3schools.com/python/ref_keyword_assert.asp

# %%
# Write your answer here

# %% [markdown]
# Uncomment the cell below to find a possible answer.

# %%
# %load code_solutions/Assertions.txt
# Assertions will throw an error when the condition fails.

# Check if the amount of datapaths contains 600 elements
assert len(testing_datapaths) == 1000
# Check if we have 200 of each
assert len(list(filter(lambda filepath: 'Arborio' in filepath[1], testing_datapaths))) == 200
assert len(list(filter(lambda filepath: 'Basmati' in filepath[1], testing_datapaths))) == 200
assert len(list(filter(lambda filepath: 'Ipsala' in filepath[1], testing_datapaths))) == 200
assert len(list(filter(lambda filepath: 'Jasmine' in filepath[1], testing_datapaths))) == 200
assert len(list(filter(lambda filepath: 'Karacadag' in filepath[1], testing_datapaths))) == 200

# %%
testing_datapaths[:2]
# Out:
# [({
#     "name": "workspaceblobstore",
#     "container_name": "azureml-blobstore-edf67872-0662-4eee-85b2-8a225f0852bb",
#     "account_name": "felixplatteaum7793200008",
#     "protocol": "https",
#     "endpoint": "core.windows.net"
#   },
#   'processed_rice/Arborio_v1/Arborio_(798).jpg'),
#  ({
#     "name": "workspaceblobstore",
#     "container_name": "azureml-blobstore-edf67872-0662-4eee-85b2-8a225f0852bb",
#     "account_name": "felixplatteaum7793200008",
#     "protocol": "https",
#     "endpoint": "core.windows.net"
#   },
#   'processed_rice/Arborio_v1/Arborio_(555).jpg')]

# %% [markdown]
# ### Step 2.4 -- Register Training and Testing Dataset
#
# We don't need to re-upload our images, but we do need to register our Training and Testing datasets as well.

# %%
training_dataset = Dataset.File.from_files(path=training_datapaths)
testing_dataset = Dataset.File.from_files(path=testing_datapaths)

training_dataset = training_dataset.register(ws,
    name=f'rice-training-set',
    description=f'The Rice Images to train, resized tot 64, 64',
    tags={'rice': ','.join(RICES), 'AI-Model': 'CNN', 'Split size': str(1 - train_test_split_factor), 'type': 'training'},
    create_new_version=True)

testing_dataset = testing_dataset.register(ws,
    name=f'rice-testing-set',
    description=f'The Rice Images to test, resized tot 64, 64',
    tags={'rice': ','.join(RICES), 'AI-Model': 'CNN', 'Split size': str(train_test_split_factor), 'type': 'testing'},
    create_new_version=True)

# %% [markdown]
# ## Finalizing
#
# Now that we have all our datasets uploaded, we can continue to the next notebook where we will learn how to Train an AI model into Azure Machine Learning.

# %%
# One last check for the dataset.
Dataset.get_all(ws)
# Out:
# {'rice-testing-set': DatasetRegistration(id='6030219e-3c8c-41eb-9463-d562f9510165', name='rice-testing-set', version=1, description='The Rice Images to test, resized tot 64, 64', tags={'rice': 'Arborio_v1,Basmati_v1,Ipsala_v1,Jasmine_v1,Karacadag_v1', 'AI-Model': 'CNN', 'Split size': '0.2', 'type': 'testing'}), 'rice-training-set': DatasetRegistration(id='a026cd74-a2c6-4c01-8471-bc7c9d0bb518', name='rice-training-set', version=1, description='The Rice Images to train, resized tot 64, 64', tags={'rice': 'Arborio_v1,Basmati_v1,Ipsala_v1,Jasmine_v1,Karacadag_v1', 'AI-Model': 'CNN', 'Split size': '0.8', 'type': 'training'}), 'resized_Karacadag_v1': DatasetRegistration(id='5376540b-f496-4031-b941-414a26696526', name='resized_Karacadag_v1', version=1, description='Karacadag_v1 images resized tot 64, 64', tags={'rice': 'Karacadag_v1', 'AI-Model': 'CNN'}), 'resized_Jasmine_v1': DatasetRegistration(id='837a6eb4-93de-45cc-80ea-8b47dc81b2c8', name='resized_Jasmine_v1', version=1, description='Jasmine_v1 images resized tot 64, 64', tags={'rice': 'Jasmine_v1', 'AI-Model': 'CNN'}), 'resized_Ipsala_v1': DatasetRegistration(id='4ab6790b-ec28-4a3c-b397-71275f58d112', name='resized_Ipsala_v1', version=1, description='Ipsala_v1 images resized tot 64, 64', tags={'rice': 'Ipsala_v1', 'AI-Model': 'CNN'}), 'resized_Basmati_v1': DatasetRegistration(id='4a5e3c95-f4ec-4942-b764-6331588217bb', name='resized_Basmati_v1', version=1, description='Basmati_v1 images resized tot 64, 64', tags={'rice': 'Basmati_v1', 'AI-Model': 'CNN'}), 'resized_Arborio_v1': DatasetRegistration(id='e3d9bc12-0f83-468a-9ac1-7e7219124f6b', name='resized_Arborio_v1', version=1, description='Arborio_v1 images resized tot 64, 64', tags={'rice': 'Arborio_v1', 'AI-Model': 'CNN'}), 'Karacadag_v1': DatasetRegistration(id='1a7c3105-f8b1-43fd-956d-a1d3b20d4f58', name='Karacadag_v1', version=1, description='', tags={}), 'Jasmine_v1': DatasetRegistration(id='67f20d87-a70d-4657-92a9-5a83a0e3711a', name='Jasmine_v1', version=1, description='', tags={}), 'Ipsala_v1': DatasetRegistration(id='0bf0349b-ac3b-4459-95ba-e0f6fdc5da38', name='Ipsala_v1', version=1, description='', tags={}), 'Basmati_v1': DatasetRegistration(id='d9c164c7-a5a1-4f6d-a050-4e4ff1c2f35a', name='Basmati_v1', version=1, description='', tags={}), 'Arborio_v1': DatasetRegistration(id='23aa2c70-2e22-4f07-aa02-fd8b6f3c10ba', name='Arborio_v1', version=1, description='', tags={})}
